# %% [markdown]
# # Preview Metadata
#
# Exploring the NYC Building Elevation and Subgrade (BES) Dataset in Python
#
# Author: Mark Bauer

# %%
import duckdb

# %%
# Printing verions of Python modules and packages with **watermark** - the IPython magic extension.
# %reload_ext watermark
# %watermark -v -p duckdb
# Out:
# Python implementation: CPython
# Python version       : 3.8.13
# IPython version      : 8.4.0
#
# duckdb: 0.10.0

# %% [markdown]
# ![cover-photo](images/dataset-cover-photo.png)
# Screenshot of data set on NYC Open Data.
#
# Link to dataset website: https://data.cityofnewyork.us/City-Government/Building-Elevation-and-Subgrade-BES-/bsin-59hv

# %%
# list files
# %ls data/
# Out:
# bes-data.parquet   nfip-data.parquet

# %% [markdown]
# # Create Table

# %%
# create a DuckDB database instance
con = duckdb.connect()

# create table of the building and elevation data named bes_data
con.sql(
    """
    CREATE TABLE bes_data AS
    FROM read_parquet('data/bes-data.parquet')
    """
)

# %% [markdown]
# # Shape of Data

# %%
# examine count of rows
con.sql("SELECT COUNT(*) AS count_rows FROM bes_data").show()
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     861876 │
# └────────────┘

# %%
# count of columns
con.sql("SELECT count(*) AS count_columns FROM (DESCRIBE bes_data)").show()
# Out:
# ┌───────────────┐
# │ count_columns │
# │     int64     │
# ├───────────────┤
# │            26 │
# └───────────────┘

# %% [markdown]
# # Column Types
# Examine column types and other metadata features. Note: In this example, any column can be null, as there is no constraint, but this information is very useful when looking at a table from a relational database.

# %%
con.sql("DESCRIBE bes_data").to_df()
# Out:
#    column_name column_type null   key default extra
# 0     the_geom     VARCHAR  YES  None    None  None
# 1          bin      BIGINT  YES  None    None  None
# 2          bbl      BIGINT  YES  None    None  None
# 3      borough      BIGINT  YES  None    None  None
# 4        block      BIGINT  YES  None    None  None
# 5          lot      BIGINT  YES  None    None  None
# 6      address     VARCHAR  YES  None    None  None
# 7      z_grade      DOUBLE  YES  None    None  None
# 8      z_floor      DOUBLE  YES  None    None  None
# 9     subgrade     VARCHAR  YES  None    None  None
# 10      notes1     VARCHAR  YES  None    None  None
# 11      notes2     VARCHAR  YES  None    None  None
# 12      notes3     VARCHAR  YES  None    None  None
# 13           x      DOUBLE  YES  None    None  None
# 14           y      DOUBLE  YES  None    None  None
# 15    latitude      DOUBLE  YES  None    None  None
# 16   longitude      DOUBLE  YES  None    None  None
# 17   pluto_bbl      BIGINT  YES  None    None  None
# 18     Council      BIGINT  YES  None    None  None
# 19      BoroCD      BIGINT  YES  None    None  None
# 20     CTLabel      DOUBLE  YES  None    None  None
# 21  BoroCT2020      BIGINT  YES  None    None  None
# 22     NTA2020     VARCHAR  YES  None    None  None
# 23     NTAName     VARCHAR  YES  None    None  None
# 24    CDTA2020     VARCHAR  YES  None    None  None
# 25    CDTAName     VARCHAR  YES  None    None  None

# %% [markdown]
# # Information Schema
# Views that describe the catalog entries of the database. Since we created a database instance from a Parquet file, the information below isn't too useful; however, the information schema becomes very useful when working with relational databases (i.e. PostgreSQL).

# %%
# tables
con.sql("SELECT * FROM information_schema.tables").df()
# Out:
#   table_catalog table_schema table_name  table_type  \
# 0        memory         main   bes_data  BASE TABLE
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
#
#    user_defined_type_catalog  user_defined_type_schema  \
# 0                        NaN                       NaN
#
#    user_defined_type_name is_insertable_into is_typed commit_action
# 0                     NaN                YES       NO          None

# %%
# columns
con.sql("SELECT * FROM information_schema.columns").df()
# Out:
#    table_catalog table_schema table_name column_name  ordinal_position  \
# 0         memory         main   bes_data    the_geom                 1
# 1         memory         main   bes_data         bin                 2
# 2         memory         main   bes_data         bbl                 3
# 3         memory         main   bes_data     borough                 4
# 4         memory         main   bes_data       block                 5
# 5         memory         main   bes_data         lot                 6
# 6         memory         main   bes_data     address                 7
# 7         memory         main   bes_data     z_grade                 8
# 8         memory         main   bes_data     z_floor                 9
# 9         memory         main   bes_data    subgrade                10
# 10        memory         main   bes_data      notes1                11
# 11        memory         main   bes_data      notes2                12
# 12        memory         main   bes_data      notes3                13
# 13        memory         main   bes_data           x                14
# 14        memory         main   bes_data           y                15
# 15        memory         main   bes_data    latitude                16
# 16        memory         main   bes_data   longitude                17
# 17        memory         main   bes_data   pluto_bbl                18
# 18        memory         main   bes_data     Council                19
# 19        memory         main   bes_data      BoroCD                20
# 20        memory         main   bes_data     CTLabel                21
# 21        memory         main   bes_data  BoroCT2020                22
# 22        memory         main   bes_data     NTA2020                23
# 23        memory         main   bes_data     NTAName                24
# 24        memory         main   bes_data    CDTA2020                25
# 25        memory         main   bes_data    CDTAName                26
#
#    column_default is_nullable data_type  character_maximum_length  \
# 0            None         YES   VARCHAR                       NaN
# 1            None         YES    BIGINT                       NaN
# 2            None         YES    BIGINT                       NaN
# 3            None         YES    BIGINT                       NaN
# 4            None         YES    BIGINT                       NaN
# 5            None         YES    BIGINT                       NaN
# 6            None         YES   VARCHAR                       NaN
# 7            None         YES    DOUBLE                       NaN
# 8            None         YES    DOUBLE                       NaN
# 9            None         YES   VARCHAR                       NaN
# 10           None         YES   VARCHAR                       NaN
# 11           None         YES   VARCHAR                       NaN
# 12           None         YES   VARCHAR                       NaN
# 13           None         YES    DOUBLE                       NaN
# 14           None         YES    DOUBLE                       NaN
# 15           None         YES    DOUBLE                       NaN
# 16           None         YES    DOUBLE                       NaN
# 17           None         YES    BIGINT                       NaN
# 18           None         YES    BIGINT                       NaN
# 19           None         YES    BIGINT                       NaN
# 20           None         YES    DOUBLE                       NaN
# 21           None         YES    BIGINT                       NaN
# 22           None         YES   VARCHAR                       NaN
# 23           None         YES   VARCHAR                       NaN
# 24           None         YES   VARCHAR                       NaN
# 25           None         YES   VARCHAR                       NaN
#
#     character_octet_length  ...  is_identity  identity_generation  \
# 0                      NaN  ...          NaN                  NaN
# 1                      NaN  ...          NaN                  NaN
# 2                      NaN  ...          NaN                  NaN
# 3                      NaN  ...          NaN                  NaN
# 4                      NaN  ...          NaN                  NaN
# 5                      NaN  ...          NaN                  NaN
# 6                      NaN  ...          NaN                  NaN
# 7                      NaN  ...          NaN                  NaN
# 8                      NaN  ...          NaN                  NaN
# 9                      NaN  ...          NaN                  NaN
# 10                     NaN  ...          NaN                  NaN
# 11                     NaN  ...          NaN                  NaN
# 12                     NaN  ...          NaN                  NaN
# 13                     NaN  ...          NaN                  NaN
# 14                     NaN  ...          NaN                  NaN
# 15                     NaN  ...          NaN                  NaN
# 16                     NaN  ...          NaN                  NaN
# 17                     NaN  ...          NaN                  NaN
# 18                     NaN  ...          NaN                  NaN
# 19                     NaN  ...          NaN                  NaN
# 20                     NaN  ...          NaN                  NaN
# 21                     NaN  ...          NaN                  NaN
# 22                     NaN  ...          NaN                  NaN
# 23                     NaN  ...          NaN                  NaN
# 24                     NaN  ...          NaN                  NaN
# 25                     NaN  ...          NaN                  NaN
#
#     identity_start  identity_increment  identity_maximum  identity_minimum  \
# 0              NaN                 NaN               NaN               NaN
# 1              NaN                 NaN               NaN               NaN
# 2              NaN                 NaN               NaN               NaN
# 3              NaN                 NaN               NaN               NaN
# 4              NaN                 NaN               NaN               NaN
# 5              NaN                 NaN               NaN               NaN
# 6              NaN                 NaN               NaN               NaN
# 7              NaN                 NaN               NaN               NaN
# 8              NaN                 NaN               NaN               NaN
# 9              NaN                 NaN               NaN               NaN
# 10             NaN                 NaN               NaN               NaN
# 11             NaN                 NaN               NaN               NaN
# 12             NaN                 NaN               NaN               NaN
# 13             NaN                 NaN               NaN               NaN
# 14             NaN                 NaN               NaN               NaN
# 15             NaN                 NaN               NaN               NaN
# 16             NaN                 NaN               NaN               NaN
# 17             NaN                 NaN               NaN               NaN
# 18             NaN                 NaN               NaN               NaN
# 19             NaN                 NaN               NaN               NaN
# 20             NaN                 NaN               NaN               NaN
# 21             NaN                 NaN               NaN               NaN
# 22             NaN                 NaN               NaN               NaN
# 23             NaN                 NaN               NaN               NaN
# 24             NaN                 NaN               NaN               NaN
# 25             NaN                 NaN               NaN               NaN
#
#     identity_cycle  is_generated  generation_expression  is_updatable
# 0              NaN           NaN                    NaN           NaN
# 1              NaN           NaN                    NaN           NaN
# 2              NaN           NaN                    NaN           NaN
# 3              NaN           NaN                    NaN           NaN
# 4              NaN           NaN                    NaN           NaN
# 5              NaN           NaN                    NaN           NaN
# 6              NaN           NaN                    NaN           NaN
# 7              NaN           NaN                    NaN           NaN
# 8              NaN           NaN                    NaN           NaN
# 9              NaN           NaN                    NaN           NaN
# 10             NaN           NaN                    NaN           NaN
# 11             NaN           NaN                    NaN           NaN
# 12             NaN           NaN                    NaN           NaN
# 13             NaN           NaN                    NaN           NaN
# 14             NaN           NaN                    NaN           NaN
# 15             NaN           NaN                    NaN           NaN
# 16             NaN           NaN                    NaN           NaN
# 17             NaN           NaN                    NaN           NaN
# 18             NaN           NaN                    NaN           NaN
# 19             NaN           NaN                    NaN           NaN
# 20             NaN           NaN                    NaN           NaN
# 21             NaN           NaN                    NaN           NaN
# 22             NaN           NaN                    NaN           NaN
# 23             NaN           NaN                    NaN           NaN
# 24             NaN           NaN                    NaN           NaN
# 25             NaN           NaN                    NaN           NaN
#
# [26 rows x 44 columns]

# %% [markdown]
# # Preview Values

# %%
# preview the data, limit to only five rows
sample_df = con.sql("SELECT * FROM bes_data LIMIT 5").to_df()

sample_df
# Out:
#                                         the_geom      bin         bbl  \
# 0   POINT (-74.22274561187417 40.52134422844183)  5128004  5075340353
# 1   POINT (-74.24179250549321 40.52875316810818)  5155392  5075960125
# 2  POINT (-74.24109012652094 40.528883822921635)  5148808  5075960131
# 3  POINT (-74.24649640323727 40.507045708438184)  5088274  5079150042
# 4   POINT (-74.24198032271697 40.51005666426356)  5087850  5078680123
#
#    borough  block  lot             address  z_grade  z_floor subgrade  ...  \
# 0        5   7534  353        78 SAVO LOOP   29.428   32.332        N  ...
# 1        5   7596  125       72 CHART LOOP   25.366   26.703        N  ...
# 2        5   7596  131       40 TIDES LANE   36.172   38.902        N  ...
# 3        5   7915   42     328 MAIN STREET   69.897   72.459        N  ...
# 4        5   7868  123  309 SLEIGHT AVENUE   74.907   79.122        N  ...
#
#    longitude   pluto_bbl Council  BoroCD  CTLabel  BoroCT2020  NTA2020  \
# 0 -74.222746  5075340353      51     503   226.01     5022601   SI0304
# 1 -74.241793  5075960125      51     503   226.02     5022602   SI0305
# 2 -74.241090  5075960131      51     503   226.02     5022602   SI0305
# 3 -74.246496  5079150042      51     503   244.01     5024401   SI0305
# 4 -74.241980  5078680123      51     503   244.01     5024401   SI0305
#
#                                   NTAName  CDTA2020  \
# 0  Annadale-Huguenot-Prince's Bay-Woodrow      SI03
# 1                  Tottenville-Charleston      SI03
# 2                  Tottenville-Charleston      SI03
# 3                  Tottenville-Charleston      SI03
# 4                  Tottenville-Charleston      SI03
#
#                                 CDTAName
# 0  SI03 South Shore (CD 3 Approximation)
# 1  SI03 South Shore (CD 3 Approximation)
# 2  SI03 South Shore (CD 3 Approximation)
# 3  SI03 South Shore (CD 3 Approximation)
# 4  SI03 South Shore (CD 3 Approximation)
#
# [5 rows x 26 columns]

# %%
# too many columns to view, examine columns by every 15
sample_df.iloc[:, :15]
# Out:
#                                         the_geom      bin         bbl  \
# 0   POINT (-74.22274561187417 40.52134422844183)  5128004  5075340353
# 1   POINT (-74.24179250549321 40.52875316810818)  5155392  5075960125
# 2  POINT (-74.24109012652094 40.528883822921635)  5148808  5075960131
# 3  POINT (-74.24649640323727 40.507045708438184)  5088274  5079150042
# 4   POINT (-74.24198032271697 40.51005666426356)  5087850  5078680123
#
#    borough  block  lot             address  z_grade  z_floor subgrade  \
# 0        5   7534  353        78 SAVO LOOP   29.428   32.332        N
# 1        5   7596  125       72 CHART LOOP   25.366   26.703        N
# 2        5   7596  131       40 TIDES LANE   36.172   38.902        N
# 3        5   7915   42     328 MAIN STREET   69.897   72.459        N
# 4        5   7868  123  309 SLEIGHT AVENUE   74.907   79.122        N
#
#                                notes1                           notes2 notes3  \
# 0  Property was Successfully Measured                             None   None
# 1  Property was Successfully Measured  Attached Garage to Living Space   None
# 2  Property was Successfully Measured                             None   None
# 3  Property was Successfully Measured                             None   None
# 4  Property was Successfully Measured                             None   None
#
#                x              y
# 0  922321.468334  129295.106289
# 1  917033.446429  132008.386296
# 2  917228.833178  132055.448538
# 3  915703.546202  124103.533995
# 4  916962.418356  125196.988173

# %%
sample_df.iloc[:, 15:]
# Out:
#     latitude  longitude   pluto_bbl  Council  BoroCD  CTLabel  BoroCT2020  \
# 0  40.521344 -74.222746  5075340353       51     503   226.01     5022601
# 1  40.528753 -74.241793  5075960125       51     503   226.02     5022602
# 2  40.528884 -74.241090  5075960131       51     503   226.02     5022602
# 3  40.507046 -74.246496  5079150042       51     503   244.01     5024401
# 4  40.510057 -74.241980  5078680123       51     503   244.01     5024401
#
#   NTA2020                                 NTAName CDTA2020  \
# 0  SI0304  Annadale-Huguenot-Prince's Bay-Woodrow     SI03
# 1  SI0305                  Tottenville-Charleston     SI03
# 2  SI0305                  Tottenville-Charleston     SI03
# 3  SI0305                  Tottenville-Charleston     SI03
# 4  SI0305                  Tottenville-Charleston     SI03
#
#                                 CDTAName
# 0  SI03 South Shore (CD 3 Approximation)
# 1  SI03 South Shore (CD 3 Approximation)
# 2  SI03 South Shore (CD 3 Approximation)
# 3  SI03 South Shore (CD 3 Approximation)
# 4  SI03 South Shore (CD 3 Approximation)

# %% [markdown]
# # Summary Statistics

# %%
# describe, examine column summary statistics
con.sql("SUMMARIZE bes_data").to_df()
# Out:
#    column_name column_type                                                min  \
# 0     the_geom     VARCHAR       POINT (-73.70028493810709 40.73982670098595)
# 1          bin      BIGINT                                            1000003
# 2          bbl      BIGINT                                            1090961
# 3      borough      BIGINT                                                  1
# 4        block      BIGINT                                                  1
# 5          lot      BIGINT                                                  0
# 6      address     VARCHAR                                          1 1 PLACE
# 7      z_grade      DOUBLE                                            -13.096
# 8      z_floor      DOUBLE                                                0.0
# 9     subgrade     VARCHAR                                                  N
# 10      notes1     VARCHAR  Property not Visible Due to Construction or Ob...
# 11      notes2     VARCHAR                    Attached Garage to Living Space
# 12      notes3     VARCHAR           Visible Door or Window in subgrade space
# 13           x      DOUBLE                                      913265.264333
# 14           y      DOUBLE                                      120977.993002
# 15    latitude      DOUBLE                                        40.49847808
# 16   longitude      DOUBLE                                       -74.25526629
# 17   pluto_bbl      BIGINT                                            1090961
# 18     Council      BIGINT                                                  1
# 19      BoroCD      BIGINT                                                101
# 20     CTLabel      DOUBLE                                                1.0
# 21  BoroCT2020      BIGINT                                            1000201
# 22     NTA2020     VARCHAR                                             BK0101
# 23     NTAName     VARCHAR                                           Allerton
# 24    CDTA2020     VARCHAR                                               BK01
# 25    CDTAName     VARCHAR     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
#
#                                                   max  approx_unique  \
# 0       POINT (-74.25526629488128 40.507487398894796)         859938
# 1                                             5799523         859098
# 2                                          5999999999         796558
# 3                                                   5              5
# 4                                               99999          13737
# 5                                                9999           2228
# 6                                         YORK AVENUE         799297
# 7                                             402.839         154473
# 8                                             404.397         157573
# 9                                                   Y              2
# 10  Vacant Lot; No Address Plate or Identification...             12
# 11  Partially Enclosed or Unenclosed Ground Floor ...              9
# 12  Visible Door or Window in subgrade space; Nega...              2
# 13                                       1067282.8231         801924
# 14                                      272622.861956         792934
# 15                                        40.91492333         851451
# 16                                       -73.70036863         856938
# 17                                         5999999999         796558
# 18                                                 51             51
# 19                                                595             71
# 20                                             1621.0           1562
# 21                                            5032300           2299
# 22                                             SI9593            257
# 23                    Yankee Stadium-Macombs Dam Park            260
# 24                                               SI95             72
# 25  SI95 Great Kills Park-Fort Wadsworth (JIA 95 A...             73
#
#                    avg                  std                 q25  \
# 0                 None                 None                None
# 1    3610723.244786953   1053306.7928804038             3089748
# 2   3517132892.0941052    1034376481.787392          3030859098
# 3    3.464081218274112   1.0262401210524326                   3
# 4    5310.378501522842   3725.9737014125703                2316
# 5   152.17001401593734    835.8620785492634                  18
# 6                 None                 None                None
# 7     53.9150124078175    42.19289508297011   23.27506689140507
# 8    58.11370394813196    42.56067271472596  27.457626218317237
# 9                 None                 None                None
# 10                None                 None                None
# 11                None                 None                None
# 12                None                 None                None
# 13   1006344.932677585   32889.642061021135   989352.3908846388
# 14  191685.08575699624   30587.626141089684   168141.3012691274
# 15   40.69271885376729  0.08394630165773868   40.62816203168676
# 16  -73.92023762419717  0.11856686241127617  -73.98162936612758
# 17  3517132892.0941052    1034376481.787392          3030859098
# 18  31.915000533719468   13.311199013322396                  22
# 19   354.5886183163239   101.29659992996822                 306
# 20  469.62122423651834    384.5512523181031   168.2372458939438
# 21   3511009.154711351   1030887.9182960566             3027142
# 22                None                 None                None
# 23                None                 None                None
# 24                None                 None                None
# 25                None                 None                None
#
#                    q50                 q75   count  null_percentage
# 0                 None                None  861876             0.00
# 1              4020085             4258395  861876             0.00
# 2           4009594779          4104636252  861876             0.00
# 3                    4                   4  861876             0.00
# 4                 4858                7516  861876             0.00
# 5                   38                  64  861876             0.00
# 6                 None                None  861876             1.97
# 7    44.36646807075309     72.672796841384  861876             0.00
# 8     48.3954936989231   77.12151609920089  861876             0.00
# 9                 None                None  861876             0.00
# 10                None                None  861876             0.00
# 11                None                None  861876            76.51
# 12                None                None  861876            45.24
# 13  1009030.9130798869  1030229.3598623187  861876             0.00
# 14  189492.75303979218   211351.7164196937  861876             0.00
# 15   40.68685977247714  40.746769070986936  861876             0.00
# 16  -73.91012300693714  -73.83528083974258  861876             0.00
# 17          4009594779          4104636252  861876             0.00
# 18                  31                  44  861876             0.00
# 19                 402                 412  861876             0.00
# 20   352.1403349954011   671.5236181792874  861876             0.00
# 21             4007312             4092692  861876             0.00
# 22                None                None  861876             0.00
# 23                None                None  861876             0.00
# 24                None                None  861876             0.00
# 25                None                None  861876             0.00

# %% [markdown]
# # Preview Null Percentage

# %%
# preview approximate null percentage, might be rounding issues given the decimal places
summarize_df = con.sql("SUMMARIZE bes_data").to_df()

summarize_df = (
    summarize_df
    .loc[:, ['column_name', 'null_percentage']]
    .sort_values(by='null_percentage', ascending=False)
)

summarize_df
# Out:
#    column_name  null_percentage
# 11      notes2            76.51
# 12      notes3            45.24
# 6      address             1.97
# 0     the_geom             0.00
# 15    latitude             0.00
# 24    CDTA2020             0.00
# 23     NTAName             0.00
# 22     NTA2020             0.00
# 21  BoroCT2020             0.00
# 20     CTLabel             0.00
# 19      BoroCD             0.00
# 18     Council             0.00
# 17   pluto_bbl             0.00
# 16   longitude             0.00
# 13           x             0.00
# 14           y             0.00
# 1          bin             0.00
# 10      notes1             0.00
# 9     subgrade             0.00
# 8      z_floor             0.00
# 7      z_grade             0.00
# 5          lot             0.00
# 4        block             0.00
# 3      borough             0.00
# 2          bbl             0.00
# 25    CDTAName             0.00

# %%
# close database connection
con.close()
