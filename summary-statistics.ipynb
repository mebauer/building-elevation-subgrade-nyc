# %% [markdown]
# # Exploring the NYC Building Elevation and Subgrade (BES) Data Set in Python
# Author: Mark Bauer

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
from IPython.display import display, HTML
import duckdb

plt.rcParams['savefig.facecolor'] = 'white'
# %matplotlib inline

# %%
# Printing verions of Python modules and packages with **watermark** - the IPython magic extension.
# %reload_ext watermark
# %watermark -v -p numpy,pandas,matplotlib,seaborn,duckdb
# Out:
# Python implementation: CPython
# Python version       : 3.8.13
# IPython version      : 8.4.0
#
# numpy     : 1.23.1
# pandas    : 1.4.3
# matplotlib: 3.5.2
# seaborn   : 0.11.2
# duckdb    : 0.10.0

# %% [markdown]
# ![cover-photo](images/dataset-cover-photo.png)
# Screenshot of data set on NYC Open Data.
#
# Link to data set website: https://data.cityofnewyork.us/City-Government/Building-Elevation-and-Subgrade-BES-/bsin-59hv

# %%
# create a DuckDB database instance
con = duckdb.connect()

# examine count of rows
con.sql("SELECT COUNT(*) AS count_rows FROM read_parquet('data/bes-data.parquet')").show()
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │     861876 │
# └────────────┘

# %%
df = con.sql("SELECT * FROM read_parquet('data/bes-data.parquet')").df()

rows, cols = df.shape
print('rows: {:,}\ncolumns: {}'.format(rows, cols))

# preview data
df.head()
# Out:
# rows: 861,876
# columns: 26
#                                         the_geom      bin         bbl  \
# 0   POINT (-74.22274561187417 40.52134422844183)  5128004  5075340353
# 1   POINT (-74.24179250549321 40.52875316810818)  5155392  5075960125
# 2  POINT (-74.24109012652094 40.528883822921635)  5148808  5075960131
# 3  POINT (-74.24649640323727 40.507045708438184)  5088274  5079150042
# 4   POINT (-74.24198032271697 40.51005666426356)  5087850  5078680123
#
#    borough   block  lot             address  z_grade  z_floor subgrade  ...  \
# 0      5.0  7534.0  353        78 SAVO LOOP   29.428   32.332        N  ...
# 1      5.0  7596.0  125       72 CHART LOOP   25.366   26.703        N  ...
# 2      5.0  7596.0  131       40 TIDES LANE   36.172   38.902        N  ...
# 3      5.0  7915.0   42     328 MAIN STREET   69.897   72.459        N  ...
# 4      5.0  7868.0  123  309 SLEIGHT AVENUE   74.907   79.122        N  ...
#
#    longitude   pluto_bbl Council  BoroCD  CTLabel  BoroCT2020  NTA2020  \
# 0 -74.222746  5075340353      51     503   226.01     5022601   SI0304
# 1 -74.241793  5075960125      51     503   226.02     5022602   SI0305
# 2 -74.241090  5075960131      51     503   226.02     5022602   SI0305
# 3 -74.246496  5079150042      51     503   244.01     5024401   SI0305
# 4 -74.241980  5078680123      51     503   244.01     5024401   SI0305
#
#                                   NTAName  CDTA2020  \
# 0  Annadale-Huguenot-Prince's Bay-Woodrow      SI03
# 1                  Tottenville-Charleston      SI03
# 2                  Tottenville-Charleston      SI03
# 3                  Tottenville-Charleston      SI03
# 4                  Tottenville-Charleston      SI03
#
#                                 CDTAName
# 0  SI03 South Shore (CD 3 Approximation)
# 1  SI03 South Shore (CD 3 Approximation)
# 2  SI03 South Shore (CD 3 Approximation)
# 3  SI03 South Shore (CD 3 Approximation)
# 4  SI03 South Shore (CD 3 Approximation)
#
# [5 rows x 26 columns]

# %% [markdown]
# # Examining Building Elevation Measurements

# %% [markdown]
# `z_grade`: The elevation of the building at it's lowest adjacent grade - the lowest point where the building touches the ground.
#
# `z_floor`: The elevation of what is estimated to be the lowest actively used floor.
#
# Definitions from the data dictionary.

# %%
# summary statistics
(df
 .loc[:, ['z_grade', 'z_floor']]
 .describe()
)
# Out:
#              z_grade        z_floor
# count  861876.000000  861876.000000
# mean       53.915012      58.113704
# std        42.192895      42.560673
# min       -13.096000       0.000000
# 25%        23.304000      27.438000
# 50%        44.328000      48.370000
# 75%        72.709250      77.063000
# max       402.839000     404.397000

# %% [markdown]
# Check for values below zero.

# %%
counts = (
    df
    .loc[df['z_grade'] < 0]
    .shape[0]
)

print('count of properties where z_grade value < 0: {:,}'.format(counts))
# Out:
# count of properties where z_grade value < 0: 11

# %%
counts = (
    df
    .loc[df['z_floor'] < 0]
    .shape[0]
)

print('count of properties where z_floor value < 0: {:,}'.format(counts))
# Out:
# count of properties where z_floor value < 0: 0

# %% [markdown]
# Check for values equal to zero.

# %%
counts = (
    df
    .loc[df['z_grade'] == 0]
    .shape[0]
)

print('count of properties where z_grade is 0 (no measurement): {:,}'.format(counts))
# Out:
# count of properties where z_grade is 0 (no measurement): 14,039

# %%
counts = (
    df
    .loc[df['z_floor'] == 0]
    .shape[0]
)

print('count of properties where z_floor is 0 (no measurement): {:,}'.format(counts))
# Out:
# count of properties where z_floor is 0 (no measurement): 14,038

# %% [markdown]
# Interesting that there is one building that doesn't reconcile. Let's examine the measurement notes.

# %%
bin_id = (
    df
    .loc[(df['z_grade'] == 0) & (df['z_floor'] != 0), 'bin']
    .values[0]
)

df.loc[df['bin'] == bin_id, ['bin', 'z_grade', 'z_floor', 'notes1']]
# Out:
#             bin  z_grade  z_floor                              notes1
# 293514  3109155      0.0   42.929  Property was Successfully Measured

# %% [markdown]
# We can leave this record in for now even with the presense of zero, but it might be worth examining in the future. The notes1 confirms that this property was successfully measured.
#
# Let's drop all records where `z_floor` is zero.

# %%
# sanity check before dropping z_floor is zero
(df
 .loc[df['z_floor'] == 0, 'notes1']
 .value_counts()
 .reset_index()
 .rename(columns={'index':'notes1', 'notes1':'count'})
)
# Out:
#                                               notes1  count
# 0  Property not Visible from Street; No Address P...  12079
# 1  Vacant Lot; No Address Plate or Identification...   1957
# 2  Property not Visible from Street; No Address P...      1
# 3  Property not Visible Due to Construction or Ob...      1

# %%
# drop all records where z_floor is zero
df = (
    df
    .loc[df['z_floor'] != 0]
    .reset_index(drop=True)
)

print('new shape of data:', df.shape)
df.head()
# Out:
# new shape of data: (847838, 26)
#                                         the_geom      bin         bbl  \
# 0   POINT (-74.22274561187417 40.52134422844183)  5128004  5075340353
# 1   POINT (-74.24179250549321 40.52875316810818)  5155392  5075960125
# 2  POINT (-74.24109012652094 40.528883822921635)  5148808  5075960131
# 3  POINT (-74.24649640323727 40.507045708438184)  5088274  5079150042
# 4   POINT (-74.24198032271697 40.51005666426356)  5087850  5078680123
#
#    borough   block  lot             address  z_grade  z_floor subgrade  ...  \
# 0      5.0  7534.0  353        78 SAVO LOOP   29.428   32.332        N  ...
# 1      5.0  7596.0  125       72 CHART LOOP   25.366   26.703        N  ...
# 2      5.0  7596.0  131       40 TIDES LANE   36.172   38.902        N  ...
# 3      5.0  7915.0   42     328 MAIN STREET   69.897   72.459        N  ...
# 4      5.0  7868.0  123  309 SLEIGHT AVENUE   74.907   79.122        N  ...
#
#    longitude   pluto_bbl Council  BoroCD  CTLabel  BoroCT2020  NTA2020  \
# 0 -74.222746  5075340353      51     503   226.01     5022601   SI0304
# 1 -74.241793  5075960125      51     503   226.02     5022602   SI0305
# 2 -74.241090  5075960131      51     503   226.02     5022602   SI0305
# 3 -74.246496  5079150042      51     503   244.01     5024401   SI0305
# 4 -74.241980  5078680123      51     503   244.01     5024401   SI0305
#
#                                   NTAName  CDTA2020  \
# 0  Annadale-Huguenot-Prince's Bay-Woodrow      SI03
# 1                  Tottenville-Charleston      SI03
# 2                  Tottenville-Charleston      SI03
# 3                  Tottenville-Charleston      SI03
# 4                  Tottenville-Charleston      SI03
#
#                                 CDTAName
# 0  SI03 South Shore (CD 3 Approximation)
# 1  SI03 South Shore (CD 3 Approximation)
# 2  SI03 South Shore (CD 3 Approximation)
# 3  SI03 South Shore (CD 3 Approximation)
# 4  SI03 South Shore (CD 3 Approximation)
#
# [5 rows x 26 columns]

# %%
# summary statistics
(df
 .loc[:, ['z_grade', 'z_floor']]
 .describe()
)
# Out:
#              z_grade        z_floor
# count  847838.000000  847838.000000
# mean       54.807705      59.075916
# std        41.961769      42.244047
# min       -13.096000       0.703000
# 25%        24.227250      28.361000
# 50%        45.095000      49.224000
# 75%        73.342750      77.704750
# max       402.839000     404.397000

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))

(df
 .loc[:, ['z_grade', 'z_floor']]
 .hist(ax=ax)
)

plt.suptitle('Histograms of Grade and Floor Heights (ft.)', fontsize=13)
plt.tight_layout()

# %% [markdown]
# **Figure xx:** Histograms of z_grade and z_floor values (ft.).
#
# Caption this for later.

# %%
fig, ax = plt.subplots(figsize=(6, 4))

df.boxplot(column=['z_grade', 'z_floor'])

plt.ylabel('\nfeet')
plt.tight_layout()

# %% [markdown]
# **Figure xx:** Boxplots of z_grade and z_floor values (ft.).
#
# Caption this for later.

# %%
fig, ax = plt.subplots(figsize=(6, 6))

sns.scatterplot(
    x=df['z_grade'],
    y=df['z_floor'],
    ax=ax
)

plt.title('z_floor vs. z_grade (ft.)')
plt.tight_layout()

# %% [markdown]
# **Figure xx:** Histograms of z_grade and z_floor values (ft.).
#
# Caption this for later.

# %%
(df
 .loc[
     (df['z_grade'] > 100)
     & (df['z_floor'] < 70)]
 .iloc[:, :-9]
)
# Out:
#                                              the_geom      bin         bbl  \
# 581783  POINT (-73.90546567085973 40.708900200415925)  4434111  4033730056
#
#         borough   block  lot            address  z_grade  z_floor subgrade  \
# 581783      4.0  3373.0   56  2115 GROVE STREET   113.93   63.443        N
#
#                                                    notes1  \
# 581783  Property was Successfully Measured; No Address...
#
#                                                    notes2 notes3  \
# 581783  Commercial, Industrial or other Non-Residentia...   None
#
#                    x              y  latitude  longitude
# 581783  1.010459e+06  197562.090818   40.7089 -73.905466

# %% [markdown]
# More review is required, but this might be a measurement error. We can leave this in for now.

# %% [markdown]
# Examine `z_grade` > `z_floor`.

# %%
counts = (
    df
    .loc[df['z_floor'] < df['z_grade']]
    .shape[0]
)

print('count of properties where z_floor is less than z_grade and z_floor is not zero: {:,}'.format(counts))
# Out:
# count of properties where z_floor is less than z_grade and z_floor is not zero: 316

# %% [markdown]
# Looks like there are 316 properties that seem to not be considered a first *occupied* floor. Let's check the notes.

# %%
# examine scenario
(df
 .loc[df['z_grade'] > df['z_floor'], ['notes1']]
 .value_counts()
)
# Out:
# notes1
# Property was Successfully Measured                                                                                                      246
# Property was Successfully Measured; No Address Plate or Identification on Building                                                       34
# Property not Visible Due to Construction or Obstruction                                                                                  13
# Property not Visible Due to Construction or Obstruction; No Address Plate or Identification on Building                                  10
# Property not Visible Due to Construction or Obstruction; No Address Plate or Identification on Building; Property Under Construction      5
# Property not Visible Due to Construction or Obstruction; Property Under Construction                                                      3
# Property was Successfully Measured; Property Under Construction                                                                           3
# Property was Successfully Measured; No Address Plate or Identification on Building; Property Under Construction                           2
# dtype: int64

# %% [markdown]
# We can leave these in, but they might not be considered a first *occupied* floor.

# %% [markdown]
# ## Calculating Height from Building Adjacent Grade to First Floor

# %%
# height from building floor to grade
df['z_floor_grade'] = df['z_floor'] - df['z_grade']

# summary stats
df['z_floor_grade'].describe()
# Out:
# count    847838.000000
# mean          4.268211
# std           3.087679
# min         -50.487000
# 25%           2.015000
# 50%           3.627000
# 75%           6.571000
# max          94.440000
# Name: z_floor_grade, dtype: float64

# %%
mean = df['z_floor_grade'].mean()

print('mean value of height from building adjacent grade to floor: {:.2f} ft.'.format(mean))
# Out:
# mean value of height from building adjacent grade to floor: 4.27 ft.

# %% [markdown]
# # Adding Borough Column
# It's useful to have a full Neighborhood Tabulation Areas (NTA) and Borough column.

# %%
# reading in NTA shape, only being used as a df and not gdf
url = 'https://data.cityofnewyork.us/api/geospatial/9nt8-h7nd?accessType=DOWNLOAD&method=export&format=Shapefile'
nta_df = gpd.read_file(url)

print('shape of data: {}'.format(nta_df.shape))
nta_df.head()
# Out:
# shape of data: (262, 12)
#    borocode  boroname countyfips nta2020             ntaname  ntaabbrev  \
# 0       3.0  Brooklyn        047  BK0101          Greenpoint      Grnpt
# 1       3.0  Brooklyn        047  BK0102        Williamsburg   Wllmsbrg
# 2       3.0  Brooklyn        047  BK0103  South Williamsburg  SWllmsbrg
# 3       3.0  Brooklyn        047  BK0104   East Williamsburg  EWllmsbrg
# 4       3.0  Brooklyn        047  BK0201    Brooklyn Heights      BkHts
#
#   ntatype cdta2020                                           cdtaname  \
# 0       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 1       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 2       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 3       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 4       0     BK02  BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...
#
#      shape_leng    shape_area  \
# 0  28912.566113  3.532121e+07
# 1  28098.027018  2.885431e+07
# 2  18250.280262  1.520896e+07
# 3  43184.772815  5.226621e+07
# 4  14312.504911  9.982322e+06
#
#                                             geometry
# 0  POLYGON ((-73.93213 40.72816, -73.93238 40.727...
# 1  POLYGON ((-73.96176 40.72523, -73.96154 40.725...
# 2  POLYGON ((-73.95024 40.70547, -73.94984 40.705...
# 3  POLYGON ((-73.92406 40.71411, -73.92404 40.714...
# 4  POLYGON ((-73.99236 40.68969, -73.99436 40.690...

# %%
# merge and retrieve nta and boro name data
nta_df = nta_df.loc[:, ['nta2020', 'boroname']]

df = df.merge(
    nta_df,
    left_on='NTA2020',
    right_on='nta2020',
    how='left'
)

df['ntaname_boro'] = df['NTAName'] + ', ' + df['boroname']

print('shape of data: {}'.format(df.shape))
df.head()
# Out:
# shape of data: (847838, 30)
#                                         the_geom      bin         bbl  \
# 0   POINT (-74.22274561187417 40.52134422844183)  5128004  5075340353
# 1   POINT (-74.24179250549321 40.52875316810818)  5155392  5075960125
# 2  POINT (-74.24109012652094 40.528883822921635)  5148808  5075960131
# 3  POINT (-74.24649640323727 40.507045708438184)  5088274  5079150042
# 4   POINT (-74.24198032271697 40.51005666426356)  5087850  5078680123
#
#    borough   block  lot             address  z_grade  z_floor subgrade  ...  \
# 0      5.0  7534.0  353        78 SAVO LOOP   29.428   32.332        N  ...
# 1      5.0  7596.0  125       72 CHART LOOP   25.366   26.703        N  ...
# 2      5.0  7596.0  131       40 TIDES LANE   36.172   38.902        N  ...
# 3      5.0  7915.0   42     328 MAIN STREET   69.897   72.459        N  ...
# 4      5.0  7868.0  123  309 SLEIGHT AVENUE   74.907   79.122        N  ...
#
#   CTLabel BoroCT2020 NTA2020                                 NTAName  \
# 0  226.01    5022601  SI0304  Annadale-Huguenot-Prince's Bay-Woodrow
# 1  226.02    5022602  SI0305                  Tottenville-Charleston
# 2  226.02    5022602  SI0305                  Tottenville-Charleston
# 3  244.01    5024401  SI0305                  Tottenville-Charleston
# 4  244.01    5024401  SI0305                  Tottenville-Charleston
#
#    CDTA2020                               CDTAName  z_floor_grade  nta2020  \
# 0      SI03  SI03 South Shore (CD 3 Approximation)          2.904   SI0304
# 1      SI03  SI03 South Shore (CD 3 Approximation)          1.337   SI0305
# 2      SI03  SI03 South Shore (CD 3 Approximation)          2.730   SI0305
# 3      SI03  SI03 South Shore (CD 3 Approximation)          2.562   SI0305
# 4      SI03  SI03 South Shore (CD 3 Approximation)          4.215   SI0305
#
#         boroname                                       ntaname_boro
# 0  Staten Island  Annadale-Huguenot-Prince's Bay-Woodrow, Staten...
# 1  Staten Island              Tottenville-Charleston, Staten Island
# 2  Staten Island              Tottenville-Charleston, Staten Island
# 3  Staten Island              Tottenville-Charleston, Staten Island
# 4  Staten Island              Tottenville-Charleston, Staten Island
#
# [5 rows x 30 columns]

# %%
# reading in NTA shape
url = 'https://data.cityofnewyork.us/api/geospatial/9nt8-h7nd?accessType=DOWNLOAD&method=export&format=Shapefile'
gdf = gpd.read_file(url)

# convert crs to 2263
gdf = gdf.to_crs(2263)

gdf['ntaname_boro'] = gdf['ntaname'] + ', ' + gdf['boroname']

print('shape of data:', gdf.shape)
gdf.head()
# Out:
# shape of data: (262, 13)
#    borocode  boroname countyfips nta2020             ntaname  ntaabbrev  \
# 0       3.0  Brooklyn        047  BK0101          Greenpoint      Grnpt
# 1       3.0  Brooklyn        047  BK0102        Williamsburg   Wllmsbrg
# 2       3.0  Brooklyn        047  BK0103  South Williamsburg  SWllmsbrg
# 3       3.0  Brooklyn        047  BK0104   East Williamsburg  EWllmsbrg
# 4       3.0  Brooklyn        047  BK0201    Brooklyn Heights      BkHts
#
#   ntatype cdta2020                                           cdtaname  \
# 0       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 1       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 2       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 3       0     BK01     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 4       0     BK02  BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...
#
#      shape_leng    shape_area  \
# 0  28912.566113  3.532121e+07
# 1  28098.027018  2.885431e+07
# 2  18250.280262  1.520896e+07
# 3  43184.772815  5.226621e+07
# 4  14312.504911  9.982322e+06
#
#                                             geometry  \
# 0  POLYGON ((1003059.997 204572.025, 1002991.367 ...
# 1  POLYGON ((994849.011 203499.267, 994911.093 20...
# 2  POLYGON ((998047.210 196303.325, 998157.901 19...
# 3  POLYGON ((1005302.497 199455.730, 1005307.792 ...
# 4  POLYGON ((986367.735 190549.239, 985813.835 19...
#
#                    ntaname_boro
# 0          Greenpoint, Brooklyn
# 1        Williamsburg, Brooklyn
# 2  South Williamsburg, Brooklyn
# 3   East Williamsburg, Brooklyn
# 4    Brooklyn Heights, Brooklyn

# %%
# average of average neighborhood grade to floor height
mean_nta = (
    df
    .groupby(by=['NTAName'])['z_floor_grade']
    .mean()
    .mean()
)

print('mean value of mean NTA height from building adjacent grade to floor: {:.2f} ft.'.format(mean_nta))
# Out:
# mean value of mean NTA height from building adjacent grade to floor: 3.82 ft.

# %%
fig, ax = plt.subplots(figsize=(6, 4))

df['z_floor_grade'].hist(ax=ax, bins=20)

plt.title('Histogram of Building Adjacent Grade to First Floor (ft.)')
plt.tight_layout()

# %% [markdown]
# **Figure xx:** Histogram of building adjacent grade to first floor (ft.).
#
# Caption this for later.

# %%
fig, ax = plt.subplots(figsize=(6, 4))

sns.boxplot(x=df["z_floor_grade"], ax=ax)

plt.title('Building Adjacent Grade to First Floor (ft.)')
plt.tight_layout()

# %% [markdown]
# Examine outlier.

# %%
df.loc[df['z_floor_grade'] < -40]
# Out:
#                                              the_geom      bin         bbl  \
# 581783  POINT (-73.90546567085973 40.708900200415925)  4434111  4033730056
#
#         borough   block  lot            address  z_grade  z_floor subgrade  \
# 581783      4.0  3373.0   56  2115 GROVE STREET   113.93   63.443        N
#
#         ... CTLabel BoroCT2020 NTA2020    NTAName  CDTA2020  \
# 581783  ...   593.0    4059300  QN0502  Ridgewood      QN05
#
#                                                  CDTAName  z_floor_grade  \
# 581783  QN05 Ridgewood-Maspeth-Middle Village (CD 5 Ap...        -50.487
#
#         nta2020  boroname       ntaname_boro
# 581783   QN0502    Queens  Ridgewood, Queens
#
# [1 rows x 30 columns]

# %% [markdown]
# Same outlier building as the previous inquiry. We can leave in for now, but probably good to examine further at some point.

# %%
# mean grade to floor height by NTA
nta_mean = (
    df
    .groupby(by='ntaname_boro')['z_floor_grade']
    .describe()
    .reset_index()
)

# preview count measured dataframe
nta_mean.head()
# Out:
#                                         ntaname_boro    count      mean  \
# 0                                    Allerton, Bronx   1648.0  5.098075
# 1                            Alley Pond Park, Queens      2.0  2.664000
# 2  Annadale-Huguenot-Prince's Bay-Woodrow, Staten...  11167.0  4.735034
# 3             Arden Heights-Rossville, Staten Island   9024.0  3.823133
# 4                          Astoria (Central), Queens   4250.0  4.041902
#
#         std    min      25%     50%    75%     max
# 0  3.770589  0.010  1.01925  5.0685  8.530  18.505
# 1  3.176324  0.418  1.54100  2.6640  3.787   4.910
# 2  3.072637  0.001  2.36050  4.0560  7.778  18.400
# 3  3.187088  0.000  1.11700  2.9030  6.165  20.415
# 4  3.150262  0.001  0.85950  3.6930  6.572  15.774

# %%
# merge dataframes to map
nta_mean_merged = gdf.merge(
    nta_mean,
    on='ntaname_boro',
    how='left'
)

# fill na with merge
nta_mean_merged['count'] = nta_mean_merged['count'].fillna(0).astype(int)
nta_mean_merged['mean'] = nta_mean_merged['mean'].round(2)

# preview
nta_mean_merged.iloc[:, -9:].head()
# Out:
#                    ntaname_boro  count  mean       std    min      25%  \
# 0          Greenpoint, Brooklyn   4815  3.30  2.951855 -0.244  0.64750
# 1        Williamsburg, Brooklyn   3387  2.45  2.981632 -0.436  0.38500
# 2  South Williamsburg, Brooklyn   2057  5.20  4.177141 -9.634  0.95400
# 3   East Williamsburg, Brooklyn   4422  2.34  2.677036  0.000  0.41225
# 4    Brooklyn Heights, Brooklyn   1432  6.18  4.065258  0.011  1.35350
#
#       50%      75%     max
# 0  2.6210  5.53600  18.832
# 1  1.0120  3.52350  18.596
# 2  4.5780  8.87500  22.246
# 3  1.1275  3.24150  16.861
# 4  7.7235  9.36425  28.288

# %%
# table of percent measured in ascending order by NTA
(nta_mean_merged
 .sort_values(by='mean')
 .loc[:, ['ntaname_boro', 'count', 'mean']]
 .head(20)
 .reset_index(drop=True)
)
# Out:
#                                          ntaname_boro  count  mean
# 0               Shirley Chisholm State Park, Brooklyn      1  0.16
# 1                     Rockaway Community Park, Queens      2  0.36
# 2                          Dyker Beach Park, Brooklyn      5  0.42
# 3                             Cunningham Park, Queens      8  0.43
# 4                      Lincoln Terrace Park, Brooklyn      1  0.53
# 5                       Holy Cross Cemetery, Brooklyn      1  0.57
# 6                            McGuire Fields, Brooklyn      3  0.74
# 7                         Montefiore Cemetery, Queens      1  0.91
# 8         Barren Island-Floyd Bennett Field, Brooklyn     17  0.96
# 9                               Soundview Park, Bronx      2  1.05
# 10      Mount Hebron & Cedar Grove Cemeteries, Queens      3  1.13
# 11                         Jamaica Bay (East), Queens      3  1.14
# 12                    Midtown-Times Square, Manhattan   1434  1.20
# 13       Mount Olivet & All Faiths Cemeteries, Queens      5  1.20
# 14     Midtown South-Flatiron-Union Square, Manhattan   1281  1.21
# 15                    Middle Village Cemetery, Queens      2  1.26
# 16  The Battery-Governors Island-Ellis Island-Libe...      3  1.27
# 17                    Great Kills Park, Staten Island      7  1.33
# 18                     Canarsie Park & Pier, Brooklyn      2  1.34
# 19                               Astoria Park, Queens      6  1.44

# %% [markdown]
# **Table xx:** Average building grade to floor height in ascending order by NTA (Top 20).

# %%
# table of percent measured in descending order by NTA
(nta_mean_merged
 .sort_values(by='mean', ascending=False)
 .loc[:, ['ntaname_boro', 'count', 'mean']]
 .head(20)
 .reset_index(drop=True)
)
# Out:
#                                         ntaname_boro  count  mean
# 0                        Inwood Hill Park, Manhattan      7  8.27
# 1             Hamilton Heights-Sugar Hill, Manhattan   1603  7.00
# 2               Upper West Side (Central), Manhattan   2720  6.66
# 3   Kingsbridge Heights-Van Cortlandt Village, Bronx    995  6.58
# 4                               Park Slope, Brooklyn   6704  6.33
# 5                    Riverdale-Spuyten Duyvil, Bronx   2691  6.20
# 6                         Brooklyn Heights, Brooklyn   1432  6.18
# 7                          Harlem (South), Manhattan   1945  6.18
# 8              Washington Heights (South), Manhattan   1203  6.15
# 9              Washington Heights (North), Manhattan    957  6.08
# 10               Bedford-Stuyvesant (East), Brooklyn   8905  6.02
# 11                        Highbridge Park, Manhattan      5  5.94
# 12         Upper West Side-Lincoln Square, Manhattan    946  5.90
# 13                     Green-Wood Cemetery, Brooklyn      6  5.89
# 14                   Sunset Park (Central), Brooklyn   4174  5.84
# 15            East Flatbush-Remsen Village, Brooklyn   3496  5.84
# 16                            Clinton Hill, Brooklyn   2221  5.84
# 17                                Morris Park, Bronx   3865  5.84
# 18                         Harlem (North), Manhattan   2477  5.81
# 19                    Kingsbridge-Marble Hill, Bronx    843  5.75

# %% [markdown]
# **Table xx:** Average building adjacent grade to floor height in descending order by NTA (Top 20).

# %%
fig, ax = plt.subplots(figsize=(8, 8))

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
cmap = plt.cm.viridis
norm = mpl.colors.BoundaryNorm([0, 3, 4, 5, 6, 7], cmap.N)

(nta_mean_merged
.plot(
    column='mean',
    legend=True,
    cmap=cmap,
    cax=cax,
    norm=norm,
    ax=ax)
)

gdf.plot(ax=ax, facecolor='None', linewidth=.4)

ax.set_title('Average Building Adjacent Grade to Floor Height by NTA (ft.)', fontsize=12)
ax.axis('off')
plt.tight_layout()
plt.savefig('figures/grade-floor-mean.png', dpi=250, bbox_inches='tight')

# %% [markdown]
# **Figure xx:** Average Building Adjacent Grade to Floor Height by Neighborhood Tabulation Area (NTA).
#
# Caption this for later.

# %% [markdown]
# # Examining Subgrade Values

# %% [markdown]
# Subgrade spaces
# > As noted in the data dictionary, a subgrade space does not need to be habitable or show residential use to be recorded – this dataset cannot speak to whether recorded subgrade spaces are being used as residences. The z_grade measurement in buildings with subgrade space is not the same as the depth of the subgrade space – there is no way of knowing that measurement from outside of the building. The methodology relies on there being external clues that indicate subgrade space. It does not represent subgrade spaces that may only be internally accessible, such as cellars that may be present in large commercial or apartment buildings. **This dataset should not be treated as an inventory of subgrade spaces in New York City.**
#
# Source: Building_Elevation_and_Subgrade_Dataset_Guidance.pdf
#
# This dataset should not be treated as an inventory of subgrade spaces in New York City. The analysis below is purely exploratory.

# %% [markdown]
# Examine Notes 2 and 3.

# %%
df.loc[:, ['notes2', 'notes3']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847838 entries, 0 to 847837
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   notes2  188421 non-null  object
#  1   notes3  472002 non-null  object
# dtypes: object(2)
# memory usage: 19.4+ MB

# %%
# notes2

with pd.option_context('display.max_colwidth', 220):

    notes2_df = (
        df
        .groupby(by='notes2')['z_floor_grade']
        .mean()
        .rename('z_floor_grade_avg')
        .round(2)
        .reset_index()
        .sort_values(by='z_floor_grade_avg', ascending=False)
        .reset_index(drop=True)
    )
    
    display(HTML(notes2_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>notes2</th>
#       <th>z_floor_grade_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Attached Garage to Living Space; Partially Enclosed or Unenclosed Ground Floor for Parking or Access</td>
#       <td>7.98</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Partially Enclosed or Unenclosed Ground Floor for Parking or Access</td>
#       <td>6.53</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Attached Garage to Living Space; Fully Enclosed Ground floor for Apartment Lobby, Parking, or Access (includes sites with visible flood vents)</td>
#       <td>6.11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Fully Enclosed Ground floor for Apartment Lobby, Parking, or Access (includes sites with visible flood vents)</td>
#       <td>5.46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Attached Garage to Living Space</td>
#       <td>4.88</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Commercial, Industrial or other Non-Residential Lowest Floor Active Use; Partially Enclosed or Unenclosed Ground Floor for Parking or Access</td>
#       <td>4.19</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Commercial, Industrial or other Non-Residential Lowest Floor Active Use; Fully Enclosed Ground floor for Apartment Lobby, Parking, or Access (includes sites with visible flood vents)</td>
#       <td>2.52</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Commercial, Industrial or other Non-Residential Lowest Floor Active Use</td>
#       <td>1.43</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Commercial, Industrial or other Non-Residential Lowest Floor Active Use; Attached Garage to Living Space</td>
#       <td>0.84</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Table xx:** Mean Adjacent Grade to Floor Height by Floor Attributes (Notes 2).
#
# Caption this for later.

# %%
# notes 3

with pd.option_context('display.max_colwidth', 220):
    
    notes3_df = (
        df
        .groupby(by='notes3')['z_floor_grade']
        .mean()
        .rename('z_floor_grade_avg')
        .round(2)
        .reset_index()
        .sort_values(by='z_floor_grade_avg', ascending=False)
        .reset_index(drop=True)
    )

    display(HTML(notes3_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>notes3</th>
#       <th>z_floor_grade_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Visible Door or Window in subgrade space; Negative grade driveway walkway leading down to subgrade space</td>
#       <td>7.62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Visible Door or Window in subgrade space</td>
#       <td>4.28</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Table xx:** Mean Adjacent Grade to Floor Height by Subgrade Space Attributes (Notes 3).
#
# Caption this for later.
